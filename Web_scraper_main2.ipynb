# %% [markdown]
# # Import libraries

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from newspaper import Article
from datetime import datetime
from dateutil import parser
import readability
import time
import random
import re
from urllib.parse import urljoin

# %% [markdown]
# # Define Core Scraping Functions, Article Extraction Function, Scrape Article List Page & Execute the Scraper

# %%
def get_page(url):
    """Fetch webpage with proper headers and error handling"""
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
        'Accept-Language': 'en-US,en;q=0.5'
    }
    try:
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()
        return response.text
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return None
def extract_metadata(soup, url):
    """Enhanced metadata extraction with multiple fallback methods"""
    metadata = {
        'title': '',
        'date': '',
        'author': '',
        'image': '',
        'description': '',
        'keywords': [],
        'canonical_url': url,
        'category': ''
    }

    # 1. TITLE EXTRACTION
    title_tag = (soup.find('meta', property='og:title') or 
                soup.find('meta', {'name': 'title'}) or
                soup.find('h1'))
    metadata['title'] = (
        title_tag['content'] if title_tag and title_tag.get('content')
        else title_tag.text.strip() if title_tag
        else soup.title.string.strip() if soup.title 
        else ''
    )

    # 2. DATE EXTRACTION (multiple fallbacks)
    date_sources = [
        soup.find('meta', property='article:published_time'),
        soup.find('meta', {'name': 'date'}),
        soup.find('time'),
        soup.find('span', class_=re.compile('date|time|published', re.I)),
        soup.find('div', class_=re.compile('date|timestamp', re.I))
    ]
    
    for source in date_sources:
        if source:
            date_str = (source.get('content') or 
                       source.get('datetime') or 
                       source.text.strip())
            if date_str:
                try:
                    metadata['date'] = parser.parse(date_str).isoformat()
                    break
                except:
                    continue
    
    # URL date fallback (e.g., /2024/03/15/article-slug)
    if not metadata['date'] and re.search(r'/(\d{4})/(\d{2})/(\d{2})/', url):
        match = re.search(r'/(\d{4})/(\d{2})/(\d{2})/', url)
        metadata['date'] = f"{match.group(1)}-{match.group(2)}-{match.group(3)}T00:00:00"

    # 3. AUTHOR EXTRACTION (multiple fallbacks)
    author_sources = [
        soup.find('meta', property='article:author'),
        soup.find('meta', {'name': 'author'}),
        soup.find('a', class_=re.compile('author|byline', re.I)),
        soup.find('span', class_=re.compile('author|byline', re.I)),
        soup.find('div', class_=re.compile('author-info', re.I)),
        soup.find('p', class_=re.compile('author|byline', re.I))
    ]
    
    for source in author_sources:
        if source:
            metadata['author'] = (
                source.get('content', '').strip() if source.name == 'meta'
                else source.text.strip()
            )
            if metadata['author']:
                # Clean author string (remove "By " prefix, etc.)
                metadata['author'] = re.sub(r'^[Bb]y\s+', '', metadata['author']).split(',')[0].split(' and ')[0]
                break

    # 4. KEYWORDS EXTRACTION (multiple fallbacks)
    keyword_sources = [
        soup.find('meta', {'name': 'keywords'}),
        soup.find('meta', {'property': 'article:tag'}),
        soup.find('meta', {'name': 'news_keywords'}),
        soup.find('div', class_=re.compile('tags|keywords', re.I)),
        soup.find('ul', class_=re.compile('tags', re.I))
    ]
    
    for source in keyword_sources:
        if source:
            if source.name == 'meta':
                content = source.get('content', '')
                metadata['keywords'] = [k.strip() for k in content.split(',') if k.strip()]
            else:
                metadata['keywords'] = [a.text.strip() for a in source.find_all('a') if a.text.strip()]
            if metadata['keywords']:
                break
    
    # Category fallback as keyword
    if not metadata['keywords']:
        metadata['keywords'] = [metadata['category']] if metadata['category'] else []

    # 5. IMAGE EXTRACTION
    image_tag = (soup.find('meta', property='og:image') or
                soup.find('meta', {'name': 'image'}) or
                soup.find('img', class_=re.compile('featured|main', re.I)))
    metadata['image'] = (
        image_tag['content'] if image_tag and image_tag.get('content')
        else image_tag['src'] if image_tag and image_tag.get('src')
        else ''
    )

    # 6. DESCRIPTION EXTRACTION
    desc_tag = (soup.find('meta', property='og:description') or
               soup.find('meta', {'name': 'description'}) or
               soup.find('p', class_=re.compile('excerpt|summary', re.I)))
    metadata['description'] = (
        desc_tag['content'] if desc_tag and desc_tag.get('content')
        else desc_tag.text.strip() if desc_tag
        else ''
    )

    # 7. CATEGORY EXTRACTION
    category_sources = [
        soup.find('meta', property='article:section'),
        soup.find('a', class_=re.compile('category|section', re.I)),
        soup.find('span', class_=re.compile('category', re.I))
    ]
    
    for source in category_sources:
        if source:
            metadata['category'] = (
                source.get('content', '').strip() if source.name == 'meta'
                else source.text.strip()
            )
            if metadata['category']:
                break
    
    # URL category fallback (e.g., /politics/article-slug)
    if not metadata['category'] and len(url.split('/')) > 3:
        potential_category = url.split('/')[3]
        if potential_category and not re.search(r'^\d+$', potential_category):
            metadata['category'] = potential_category.capitalize()

    return metadata
def clean_text(text):
    """Clean extracted article text"""
    if not text:
        return ''
    # Remove multiple whitespaces
    text = re.sub(r'\s+', ' ', text)
    # Remove leading/trailing whitespace
    return text.strip()

# %%
def extract_article(url):
    """Extract complete article information"""
    print(f"Processing: {url}")
    html = get_page(url)
    if not html:
        return None
    
    # Parse with BeautifulSoup
    soup = BeautifulSoup(html, 'html.parser')
    
    # Get metadata
    article_data = extract_metadata(soup, url)
    
    # Extract main content using readability
    doc = readability.Document(html)
    content_html = doc.summary()
    content_soup = BeautifulSoup(content_html, 'html.parser')
    article_data['content'] = clean_text(content_soup.get_text())
    
    # Extract category from URL or breadcrumbs
    article_data['category'] = extract_category(url, soup)
    
    # Estimate reading time (200 words per minute)
    word_count = len(article_data['content'].split())
    article_data['reading_time'] = max(1, round(word_count / 200))
    
    # Add processing timestamp
    article_data['scraped_at'] = datetime.now().isoformat()
    
    return article_data

def extract_category(url, soup):
    """Extract category from URL or breadcrumbs"""
    # Try breadcrumbs first
    breadcrumbs = soup.find_all('a', class_=re.compile('breadcrumb|category', re.I))
    if breadcrumbs and len(breadcrumbs) > 1:
        return breadcrumbs[-2].text.strip()
    
    # Fallback to URL path
    parts = url.split('/')
    if len(parts) > 3:
        return parts[3].capitalize()
    
    return ''

# %%
def scrape_news_list(base_url, num_pages=1):
    """Scrape multiple pages of news listings with robust pagination handling"""
    all_articles = []
    next_page_url = base_url  # Start with the base URL
    
    for page in range(1, num_pages + 1):
        print(f"Scraping page {page}... Current URL: {next_page_url}")
        html = get_page(next_page_url)
        if not html:
            print(f"Failed to fetch page {page}")
            break
            
        soup = BeautifulSoup(html, 'html.parser')
        
        # 1. Find all article elements (multiple possible selectors)
        articles = (soup.find_all('article') or 
                   soup.find_all('div', class_=re.compile('article|post|item', re.I)) or
                   soup.find_all('h3', class_=re.compile('title|headline', re.I)))
        
        if not articles:
            print("No articles found on this page. Check selectors.")
            break
        
        # 2. Process each article
        for item in articles:
            link = item.find('a', href=True)
            if not link:
                continue
                
            article_url = urljoin(base_url, link['href'])
            
            # Check for duplicates
            if not any(a.get('canonical_url') == article_url for a in all_articles):
                try:
                    article_data = extract_article(article_url)
                    if article_data:
                        all_articles.append(article_data)
                        print(f"✓ Added: {article_data.get('title', 'No title')[:50]}...")
                except Exception as e:
                    print(f"Error processing {article_url}: {str(e)}")
                
                # Respectful delay between article requests
                time.sleep(random.uniform(1, 3))
        
        # 3. Find next page URL (handling multiple pagination patterns)
        next_page_url = None
        
        # Pattern 1: Standard /page/X pattern
        if f"/page/{page + 1}" in html:
            next_page_url = urljoin(base_url, f"/page/{page + 1}")
        
        # Pattern 2: "Next" button link
        next_button = (soup.find('a', class_=re.compile('next|page-next', re.I)) or
                     soup.find('a', string=re.compile('next|suivant|»', re.I)))
        if next_button and next_button.get('href'):
            next_page_url = urljoin(base_url, next_button['href'])
        
        # Pattern 3: Infinite scroll with data attributes
        if not next_page_url:
            load_more = soup.find('div', attrs={'data-page': str(page + 1)})
            if load_more:
                next_page_url = f"{base_url}?page={page + 1}"
        
        if not next_page_url:
            print(f"No next page found after page {page}")
            break
        
        # Respectful delay between page requests
        time.sleep(random.uniform(2, 4))
    
    print(f"\nCompleted scraping. Found {len(all_articles)} unique articles.")
    return all_articles

# %% [markdown]
# # Application of the algorithme for example usage with telquel.ma

# %%
base_url = "https://telquel.ma"
articles = scrape_news_list(base_url, num_pages=2)

# Convert to DataFrame
df = pd.DataFrame(articles)

# Display results
print(f"Scraped {len(df)} articles")
df.head()
# Out:
# Scraping page 1... Current URL: https://telquel.ma
# Processing: https://telquel.ma/2025/08/05/smartphones-a-29-dirhams-larnaque-usurpant-le-logo-delectroplanet-qui-prolifere-sur-facebook_1945346
# ✓ Added:   Smartphones à 29 dirhams : l’arnaque usurpant le...
# Processing: https://telquel.ma/categorie/maroc/societe
# ✓ Added:   Société...
# Processing: https://telquel.ma/2025/08/05/hicham-ait-menna-fragilise-vers-un-possible-changement-de-presidence-au-wac_1945289
# ✓ Added:   Hicham Aït Menna fragilisé : vers un possible ch...
# Processing: https://telquel.ma/categorie/sport
# ✓ Added:   Sport...
# Processing: https://telquel.ma/2025/08/05/subvention-pour-une-ecloserie-de-palourdes-la-reponse-de-zakia-driouich-ravive-la-controverse_1945264
# ✓ Added:   Subvention pour une écloserie de palourdes : la ...
# Processing: https://telquel.ma/categorie/maroc/politique
# ✓ Added:   Politique...
# Processing: https://telquel.ma/instant-t/2025/08/05/la-medina-de-fes-inscrite-au-registre-de-lalecso-du-patrimoine-architectural-et-urbain_1945331/
# ✓ Added:   La médina de Fès inscrite au registre de l’ALECS...
# Processing: https://telquel.ma/categorie/culture
# ✓ Added:   Culture...
# Processing: https://telquel.ma/instant-t/2025/08/05/retraites-les-desequilibres-structurels-persistent-en-2024_1945328/
# ✓ Added:   Retraites : les déséquilibres structurels persis...
# Processing: https://telquel.ma/instant-t/2025/08/05/israel-reautorise-lentree-partielle-des-marchandises-privees-dans-gaza_1945302/
# ✓ Added:   Israël réautorise l’entrée partielle des marchan...
# Processing: https://telquel.ma/instant-t/2025/08/05/des-passagers-juifs-recoivent-des-plateaux-repas-tagues-free-palestine-sur-un-vol-iberia_1945298/
# ✓ Added:   Des passagers juifs reçoivent des plateaux-repas...
# Processing: https://telquel.ma/instant-t/2025/08/05/a-alger-le-conseiller-de-trump-reaffirme-le-soutien-americain-a-linitiative-marocaine-dautonomie-du-sahara_1945295/
# ✓ Added:   À Alger, le conseiller de Trump réaffirme le sou...
# Processing: https://telquel.ma/instant-t/2025/08/04/foot-250-mdh-pour-une-transformation-structurelle-du-raja_1945059/
# ✓ Added:   Foot : 250 MDH pour une transformation structure...
# Processing: https://telquel.ma/2025/08/01/entre-elan-et-friction_1944535
# ✓ Added:   Entre élan et friction...
# Processing: https://telquel.ma/categorie/opinions/edito
# ✓ Added:   Édito...
# Processing: https://telquel.ma/2025/07/31/maroc-algerie-lappel-de-la-raison-et-du-coeur_1944677
# ✓ Added:   Maroc/Algérie : l’appel de la raison… et du cœur...
# Processing: https://telquel.ma/categorie/opinions/notre-epoque
# ✓ Added:   Notre époque...
# Processing: https://telquel.ma/2025/08/01/chan-2025-anatomie-dun-cafouillage_1944588
# ✓ Added:   CHAN 2025 : anatomie d’un CAFouillage...
# Processing: https://telquel.ma/categorie/sport/football
# ✓ Added:   Football...
# Processing: https://telquel.ma/2025/08/01/le-boualem-la-famine-a-gaza-et-le-reveil-tardif-de-lempire_1944480
# ✓ Added:   Le Boualem, la famine à Gaza et le réveil tardif...
# Processing: https://telquel.ma/categorie/opinions/zakariaboualem
# ✓ Added:   Zakaria Boualem...
# Processing: https://telquel.ma/2025/07/29/fatim-zahra-bouazzaoui-click-doc-le-sante-ne-peut-pas-etre-pensee-hors-du-terrain_1944348
# ✓ Added:   Fatima Zahra Bouazzaoui, Click Doc : “L’e-santé ...
# Processing: https://telquel.ma/categorie/diplomatie-3
# ✓ Added:   Diplomatie...
# Processing: https://telquel.ma/categorie/economie
# ✓ Added:   Économie...
# Processing: https://telquel.ma/instant-t/2025/08/05/onu-23-femmes-casques-bleus-issues-de-14-pays-formees-a-agadir_1945281/
# ✓ Added:   ONU : 23 femmes “casques bleus” issues de 14 pay...
# Processing: https://telquel.ma/categorie/linstant-t
# ✓ Added:   Instant T...
# Processing: https://telquel.ma/2025/08/05/stellantis-kenitra-expansion-535000-vehicles-60-local-integration-and-3100-jobs-at-stake_1944607
# ✓ Added:   Stellantis Kenitra Expansion: 535,000 vehicles, ...
# Processing: https://telquel.ma/categorie/telquel-english
# ✓ Added:   TelQuel English...
# Processing: https://telquel.ma/2025/08/01/british-withdrawal-from-xlinks-can-morocco-still-dream-of-being-a-green-electricity-exporter_1941349
# ✓ Added:   British withdrawal from Xlinks: Can Morocco stil...
# Processing: https://telquel.ma/2025/07/30/food-distribution-whos-driving-up-prices_1942775
# ✓ Added:   Food distribution: who’s driving up prices?...
# Processing: https://telquel.ma/2025/07/30/casablanca-ain-sebaa-zoo-opening-scheduled-for-october_1942845
# ✓ Added:   Casablanca: Aïn Sebaâ Zoo opening scheduled for ...
# Processing: https://telquel.ma/2025/08/05/notre-bilan-2024-2025-entre-succes-ideologique-et-fragilite-interne-le-sahel-dans-tous-ses-etats_1945216
# ✓ Added:   [Notre bilan 2024-2025] Entre succès idéologique...
# Processing: https://telquel.ma/categorie/monde/afrique
# ✓ Added:   Afrique...
# Processing: https://telquel.ma/instant-t/2025/08/05/jusqua-47c-cette-semaine-dans-plusieurs-provinces-du-royaume_1945266/
# ✓ Added:   Jusqu’à 47°C cette semaine dans plusieurs provin...
# Processing: https://telquel.ma/instant-t/2025/08/05/les-femmes-principales-victimes-dintimidation-numerique-au-maroc-selon-lassociation-tahadi_1945236/
# ✓ Added:   Les femmes, principales victimes d’intimidation ...
# Processing: https://telquel.ma/instant-t/2025/08/05/acwa-power-developpera-les-centrales-solaires-noor-2-et-3-a-midelt_1945250/
# ✓ Added:   Acwa Power développera les centrales solaires No...
# Processing: https://telquel.ma/instant-t/2025/08/05/mali-liberation-de-quatre-marocains-enleves-au-sahel-en-janvier_1945246/
# ✓ Added:   Mali : libération de quatre Marocains enlevés au...
# Processing: https://telquel.ma/instant-t/2025/08/05/credits-en-2024-le-taux-dendettement-des-marocains-etait-de-34-en-moyenne_1945232/
# ✓ Added:   Crédits : en 2024, le taux d’endettement des Mar...
# Processing: https://telquel.ma/instant-t/2025/08/05/marrakech-un-caid-suspendu-pour-corruption_1945230/
# ✓ Added:   Marrakech : un caïd suspendu pour corruption...
# Processing: https://telquel.ma/2025/07/31/anouar-azelmat-co-fondateur-de-menbita-lenjeu-est-de-permettre-aux-marocains-issus-de-la-diaspora-de-candidater-pour-un-retour-au-maroc_1944190
# ✓ Added:   Anouar Azelmat, co-fondateur de Menbita : “L’enj...
# Processing: https://telquel.ma/categorie/diaspora
# ✓ Added:   Diaspora...
# Processing: https://telquel.ma/2025/07/17/nous-restons-des-moros-la-chasse-aux-immigres-nord-africains-embrase-lespagne_1942497
# ✓ Added:   “Non aux Moros” : l’Espagne en proie à ses démon...
# Processing: https://telquel.ma/instant-t/2025/07/09/le-pjd-cherche-a-se-renforcer-au-sein-de-la-diaspora_1941651/
# ✓ Added:   Le PJD cherche à se renforcer au sein de la dias...
# Processing: https://telquel.ma/2025/06/26/festival-litteraire-a-lille-la-romanciere-samira-el-ayachi-cree-un-monde-ouvert_1939837
# ✓ Added:   Festival littéraire : à Lille, la romancière Sam...
# Processing: https://telquel.ma/categorie/diaspora/artistes-et-identites
# ✓ Added:   Artistes et identités...
# Processing: https://telquel.ma/instant-t/2025/08/04/lespagne-dement-avoir-retire-son-drapeau-des-ilots-tierra-et-mar-face-au-maroc_1945203/
# ✓ Added:   L’Espagne dément avoir retiré son drapeau des îl...
# Processing: https://telquel.ma/instant-t/2025/08/04/norvege-mohamed-el-khalil-binebine-parmi-les-finishers-du-norseman-xtreme-triathlon-2025_1945199/
# ✓ Added:   Norvège : Mohamed El Khalil Binebine parmi les f...
# Processing: https://telquel.ma/instant-t/2025/08/04/cote-divoire-le-maroc-au-coeur-du-defile-militaire-du-7-aout-a-bouake_1945189/
# ✓ Added:   Côte d’Ivoire : le Maroc au cœur du défilé milit...
# Processing: https://telquel.ma/2025/08/04/tribune-tourisme-ce-que-madere-fait-mieux-que-le-maroc_1945066
# ✓ Added:   [Tribune] Tourisme : ce que Madère fait mieux qu...
# Processing: https://telquel.ma/categorie/tourisme-2
# ✓ Added:   Tourisme...
# Processing: https://telquel.ma/2025/07/25/je-te-donnerai-marrakech-lepopee-de-yahya-u-tafuft-caid-berbere-de-safi-au-xvie-siecle_1944009
# ✓ Added:   “Je te donnerai Marrakech” : l’épopée de Yahyā U...
# Processing: https://telquel.ma/categorie/culture/livres/qitab/conseils-de-qitab
# ✓ Added:   Conseils de Qitab...
# Processing: https://telquel.ma/2025/07/25/la-ville-nouvelle-de-tetouan-1860-1856-mostafa-akalay-nasser-devoile-un-pan-meconnu-de-lhistoire-de-la-ville_1943998
# ✓ Added:   “La ville nouvelle de Tétouan (1860-1856)” :  Mo...
# Processing: https://telquel.ma/2025/07/25/nouvelle-geographie-du-maroc-volumes-1-2-et-3-comprendre-le-maroc-du-21e-siecle_1943968
# ✓ Added:   “Nouvelle Géographie du Maroc, volumes 1, 2 et 3...
# Processing: https://telquel.ma/2025/07/18/the-key-lessons-for-africa-from-the-current-geopolitical-developments_1943119
# ✓ Added:   The key lessons for Africa from the Current Geop...
# Processing: https://telquel.ma/instant-t/2025/08/04/le-patrimoine-financier-des-menages-marocains-atteint-plus-d11-milliard-de-dirhams_1945167/
# ✓ Added:   Le patrimoine financier des ménages marocains at...
# Processing: https://telquel.ma/instant-t/2025/08/04/suite-aux-directives-royales-laftit-lance-les-preparatifs-des-elections-2026_1945038/
# ✓ Added:   Suite aux directives royales, Laftit lance les p...
# Processing: https://telquel.ma/instant-t/2025/08/01/lautorisation-de-quitter-le-territoire-pour-les-fonctionnaires-inconstitutionnelle-pour-ouahbi_1944948/
# ✓ Added:   L’autorisation de quitter le territoire pour les...
# Processing: https://telquel.ma/instant-t/2025/08/04/biennale-dart-de-venise-amina-agueznay-representera-le-maroc-avec-le-projet-as%c7%9d%e1%b9%ad%e1%b9%ada_1945087/
# ✓ Added:   Biennale d’art de Venise : Amina Agueznay représ...
# Processing: https://telquel.ma/categorie/contenu-partenaire-2
# ✓ Added:   Contenu partenaire...
# Processing: https://telquel.ma/2025/07/23/imane-loubane-drh-de-lafargeholcim-maroc-le-ciment-des-talents_1943529
# ✓ Added:   Imane Loubane, DRH de LafargeHolcim Maroc, le ci...
# Processing: https://telquel.ma/categorie/news-tech/whos-who-drh
# ✓ Added:   Who’s Who DRH...
# Processing: https://telquel.ma/2025/07/16/technopark-sand-to-green-la-data-pour-reverdir-le-desert_1942731
# ✓ Added:   Technopark : Sand to Green, la data pour reverdi...
# Processing: https://telquel.ma/categorie/news-tech
# ✓ Added:   News tech...
# Processing: https://telquel.ma/sponsors/al-akhawayn-university-un-modele-douverture-internationale-enracine-dans-lexcellence-marocaine_1942311
# ✓ Added:   Al Akhawayn University : un modèle d’ouverture i...
# Processing: https://telquel.ma/categorie/etudes
# ✓ Added:   Etudes...
# Processing: https://telquel.ma/sponsors/le-groupe-akdital-annonce-lacquisition-de-abdul-rahman-al-mishari-hospital-a-riyadh-en-arabie-saoudite_1944282
# ✓ Added:   Le Groupe AKDITAL annonce l’acquisition de Abdul...
# Processing: https://telquel.ma/categorie/healthtech
# ✓ Added:   Healthtech...
# Processing: https://telquel.ma/2025/07/24/souverainete-sanitaire-un-hub-marocain-pour-la-sante-en-afrique_1943685
# ✓ Added:   Souveraineté sanitaire : un hub marocain pour la...
# Processing: https://telquel.ma/categorie/gigalab
# ✓ Added:   gigalab...
# Processing: https://telquel.ma/2025/07/23/can-2025-le-maroc-face-au-test-de-la-souverainete-sanitaire_1943538
# ✓ Added:   CAN 2025 : Le Maroc face au test de la souverain...
# Processing: https://telquel.ma/sponsors/karim-zaher-pdg-de-gigalab-la-can-2025-doit-aussi-etre-un-succes-sanitaire_1943161
# ✓ Added:   Karim Zaher, PDG de Gigalab : « La CAN 2025 doit...
# Processing: https://telquel.ma/instant-t/2025/08/04/biathlon-paul-mehdi-benhayoun-veut-representer-le-maroc-aux-jo-dhiver-2026_1945173/
# ✓ Added:   Biathlon : Paul Mehdi Benhayoun veut représenter...
# Processing: https://telquel.ma/instant-t/2025/08/04/tanger-tetouan-al-hoceima-175-mdh-pour-soutenir-lentrepreneuriat-et-la-mobilite-des-jeunes_1945165/
# ✓ Added:   Tanger : 1,75 million de dirhams pour soutenir l...
# Processing: https://telquel.ma/instant-t/2025/07/31/le-conseil-de-la-concurrence-tord-le-bras-a-glovo_1944723/
# ✓ Added:   Le Conseil de la concurrence tord le bras à Glov...
# Processing: https://telquel.ma/instant-t/2025/07/30/maroc-2%e1%b5%89-pays-africain-le-mieux-classe-en-education-en-2025_1944491/
# ✓ Added:   Maroc : 2ᵉ pays africain le mieux classé en éduc...
# Processing: https://telquel.ma/instant-t/2025/07/30/partenariat-ocp-ambipar-100-000-hectares-de-paturages-degrades-a-restaurer-au-bresil_1944465/
# ✓ Added:   Partenariat OCP-Ambipar : 100 000 hectares de pâ...
# Processing: https://telquel.ma/instant-t/2025/07/30/le-deficit-commercial-saggrave-a-16186-milliards-de-dh-a-fin-juin-2025_1944463/
# ✓ Added:   Le déficit commercial s’aggrave à 161,86 milliar...
# Processing: https://telquel.ma/instant-t/2025/07/30/aeronautique-les-exportations-augmentent-de-88-a-fin-juin_1944460/
# ✓ Added:   Aéronautique : les exportations augmentent de 8,...
# Processing: https://telquel.ma/2025/05/08/etats-financiers-telquel-media-et-telquel-digital_1931600
# ✓ Added:   Etats financiers TelQuel media et TelQuel digita...
# Processing: https://telquel.ma/instant-t/2023/11/03/ocp-les-etats-unis-annoncent-la-reduction-des-droits-de-douane-sur-les-exportations-dengrais-phosphates_1839329/
# ✓ Added:   OCP : les États-Unis annoncent la réduction des ...
# Processing: https://telquel.ma/2023/07/29/cosumar-communication-financiere_1824044
# ✓ Added:   COSUMAR : Communication financière...
# Processing: https://telquel.ma/2023/04/27/etat-de-synthese-telquel-digital-2022_1809511
# ✓ Added:   Etat de synthèse TELQUEL DIGITAL 2022...
# Processing: https://telquel.ma/2025/07/18/shell-fait-vibrer-lete-marocain-avec-b7amasna-la3bin_1943127
# ✓ Added:   Shell fait vibrer l’été marocain avec “B7amasna ...
# Processing: https://telquel.ma/2025/06/24/marche-de-loccasion-au-maroc-une-dynamique-en-pleine-acceleration_1939087
# ✓ Added:   Marché de l’occasion au Maroc : une dynamique en...
# Processing: https://telquel.ma/2025/06/13/cap-sur-lete-2025-a-mazagan-beach-golf-resort-activites-palpitantes-soin-precieux-et-plaisirs-infinis_1937518
# ✓ Added:   Cap sur l’été 2025 à Mazagan Beach & Golf Resort...
# Processing: https://telquel.ma/2025/06/02/al-filahi-cash-sassocie-a-ria-money-transfer-pour-elargir-lacces-aux-transferts-internationaux_1935972
# ✓ Added:   AL FILAHI CASH s’associe à RIA Money Transfer po...
# Scraping page 2... Current URL: https://telquel.ma/page/2
# Processing: https://telquel.ma/instant-t/2025/07/29/fete-du-trone-le-roi-mohammed-vi-met-laccent-sur-lemploi-les-services-sociaux-et-le-developpement-regional_1944453/
# ✓ Added:   Fête du trône : le roi Mohammed VI met l’accent ...
# Processing: https://telquel.ma/categorie/economie/emploi
# ✓ Added:   Emploi...
# Processing: https://telquel.ma/instant-t/2025/07/29/le-roi-mohammed-vi-recoit-le-wali-de-bank-al-maghrib_1944448/
# ✓ Added:   Le roi Mohammed VI reçoit le Wali de Bank Al-Mag...
# Processing: https://telquel.ma/instant-t/2025/07/29/revolut-confirme-prospecter-le-marche-marocain-en-vue-dune-implantation_1944441/
# ✓ Added:   Revolut confirme prospecter le marché marocain e...
# Processing: https://telquel.ma/categorie/economie/banques
# ✓ Added:   Banques...
# Processing: https://telquel.ma/2025/07/29/des-cartes-bancaires-revolut-deja-au-maroc-attention-arnaque_1944388
# ✓ Added:   Des cartes bancaires Revolut déjà au Maroc ? Att...
# Processing: https://telquel.ma/instant-t/2025/07/29/tourisme-les-recettes-de-lactivite-atteignent-54-milliards-de-dh-en-progression-de-96-a-fin-juin-2025_1944393/
# ✓ Added:   Tourisme : les recettes de l’activité atteignent...
#
# Completed scraping. Found 94 unique articles.
# Scraped 94 articles
#                                                title                 date  \
# 0    Smartphones à 29 dirhams : l’arnaque usurpan...  2025-08-05T00:00:00
# 1                                            Société                 None
# 2    Hicham Aït Menna fragilisé : vers un possibl...  2025-08-05T00:00:00
# 3                                              Sport                 None
# 4    Subvention pour une écloserie de palourdes :...  2025-08-05T00:00:00
#
#            author                                              image  \
# 0  Amine Belghazi  https://cdn.telquel.ma/content/uploads/2025/08...
# 1                  https://cdn.telquel.ma/content/themes/telquel/...
# 2   Younes Saoury  https://cdn.telquel.ma/content/uploads/2025/08...
# 3                  https://cdn.telquel.ma/content/themes/telquel/...
# 4   Younes Saoury  https://cdn.telquel.ma/content/uploads/2025/08...
#
#                                          description  \
# 0  Des faux sites clonant Electroplanet inondent ...
# 1                 L'actualité du Maroc tel qu'il est
# 2  Un an après son élection, Hicham Aït Menna, pr...
# 3                 L'actualité du Maroc tel qu'il est
# 4  Zakia Driouich a défendu dans une réponse écri...
#
#                                             keywords  \
# 0  [arnaques, Electroplanet, facebook, fraude, Om...
# 1                                                 []
# 2  [Al-Aïn, CAF, Coupe du monde des clubs, footba...
# 3                                                 []
# 4  [Aquaculture, clientélisme, écloserie de palou...
#
#                                        canonical_url    category  \
# 0  https://telquel.ma/2025/08/05/smartphones-a-29...  Diplomatie
# 1         https://telquel.ma/categorie/maroc/societe   Instant T
# 2  https://telquel.ma/2025/08/05/hicham-ait-menna...   Instant T
# 3                 https://telquel.ma/categorie/sport   Instant T
# 4  https://telquel.ma/2025/08/05/subvention-pour-...    Économie
#
#                                              content  reading_time  \
# 0  Depuis plusieurs mois, des dizaines de pages f...             1
# 1                                                                1
# 2  Le Wydad Athletic Club est à l’arrêt. Sportive...             1
# 3                                                                1
# 4  Zakia Driouich a défendu dans une réponse écri...             1
#
#                    scraped_at
# 0  2025-08-05T15:50:58.234034
# 1  2025-08-05T15:51:00.624521
# 2  2025-08-05T15:51:03.933983
# 3  2025-08-05T15:51:07.143142
# 4  2025-08-05T15:51:09.378114

# %% [markdown]
# ## Save to CSV

# %%
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
filename = f"news_articles_{timestamp}.csv"
df.to_csv(filename, index=False)
print(f"Saved to {filename}")

# Basic analysis
# %%
print("\nCategories distribution:")
print(df['category'].value_counts())

print("\nTop authors:")
print(df['author'].value_counts().head(5))
# Out:
# Saved to news_articles_20250805_155807.csv
#
# Categories distribution:
# category
# Économie                    33
# Instant T                   28
# Conseils de Qitab            6
# TelQuel English              4
# Diaspora                     4
# gigalab                      4
# Com d'entreprise             4
# Diplomatie                   2
# Football                     2
# Édito                        1
# Contenu partenaire           1
# Tourisme                     1
# News tech                    1
# Who’s Who DRH                1
# Etudes                       1
# Communication financière     1
# Name: count, dtype: int64
#
# Top authors:
# author
#                   31
# La Rédaction      29
# Telquel Impact     5
# Telquel            5
# Younes Saoury      4
# Name: count, dtype: int64

# %% [markdown]
# # Save as JSON

# %%
import json
from datetime import datetime
import pandas as pd
from pandas.api.types import is_datetime64_any_dtype

class DateTimeEncoder(json.JSONEncoder):
    """Custom JSON encoder for datetime objects"""
    def default(self, obj):
        if isinstance(obj, (datetime, pd.Timestamp)):
            return obj.isoformat()
        elif isinstance(obj, pd.Timedelta):
            return str(obj)
        elif isinstance(obj, pd.NA):
            return None
        elif isinstance(obj, (pd.Series, pd.DataFrame)):
            return obj.to_dict()
        return super().default(obj)

def save_news_data(df, base_filename="news_articles"):
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    json_filename = f"{base_filename}_{timestamp}.json"
    
    # Convert datetime columns to strings
    datetime_cols = df.select_dtypes(include=['datetime64', 'datetimetz']).columns
    for col in datetime_cols:
        df[col] = df[col].apply(lambda x: x.isoformat() if pd.notna(x) else None)
    
    # Prepare metadata with safe date handling
    date_range = {}
    if 'date' in df.columns:
        try:
            if is_datetime64_any_dtype(df['date']):
                valid_dates = df[df['date'].notna()]
                if not valid_dates.empty:
                    date_range = {
                        "start": str(valid_dates['date'].min()),
                        "end": str(valid_dates['date'].max())
                    }
        except Exception as e:
            print(f"Warning: Could not process date range - {str(e)}")
    
    output_data = {
        "metadata": {
            "source": "Web Scraper",
            "version": "1.0",
            "export_date": datetime.now().isoformat(),
            "article_count": len(df),
            "columns": list(df.columns),
            "date_range": date_range
        },
        "articles": json.loads(df.to_json(orient='records', date_format='iso'))
    }
    
    # Save with custom encoder
    with open(json_filename, 'w', encoding='utf-8') as f:
        json.dump(output_data, f, 
                 ensure_ascii=False, 
                 indent=2,
                 cls=DateTimeEncoder)
    
    print(f" Successfully saved {len(df)} articles to {json_filename}")
    return json_filename

def print_analysis(df):
    """Safe analysis printing with robust date handling"""
    print("\n Data Analysis Summary")
    print("=" * 40)
    
    # Categories
    if 'category' in df.columns:
        print("\n Categories distribution:")
        print(df['category'].value_counts(dropna=False).head(10))
    
    # Authors
    if 'author' in df.columns:
        print("\n Top Authors:")
        print(df['author'].value_counts(dropna=False).head(5))
    
    # Dates
    if 'date' in df.columns:
        try:
            # Ensure we have datetime type
            if not is_datetime64_any_dtype(df['date']):
                df['date'] = pd.to_datetime(df['date'], errors='coerce')
            
            valid_dates = df[df['date'].notna()]
            if not valid_dates.empty:
                print("\n Date Range:")
                print(f"Earliest: {valid_dates['date'].min()}")
                print(f"Latest: {valid_dates['date'].max()}")
                
                print("\n Articles by Month:")
                monthly = valid_dates['date'].dt.to_period('M').value_counts().sort_index()
                print(monthly.head(12))
            else:
                print("\n No valid dates found")
        except Exception as e:
            print(f"\n Date analysis failed: {str(e)}")
    
    print("=" * 40)

# Usage example:
if __name__ == "__main__":
    json_file = save_news_data(df)
    print_analysis(df)
# Out:
#  Successfully saved 94 articles to news_articles_20250805_165308.json
#
#  Data Analysis Summary
# ========================================
#
#  Categories distribution:
# category
# Économie             33
# Instant T            28
# Conseils de Qitab     6
# TelQuel English       4
# Diaspora              4
# gigalab               4
# Com d'entreprise      4
# Diplomatie            2
# Football              2
# Édito                 1
# Name: count, dtype: int64
#
#  Top Authors:
# author
#                   31
# La Rédaction      29
# Telquel Impact     5
# Telquel            5
# Younes Saoury      4
# Name: count, dtype: int64
#
#  Date Range:
# Earliest: 2023-04-27 00:00:00
# Latest: 2025-08-05 00:00:00
#
#  Articles by Month:
# date
# 2023-04     1
# 2023-07     1
# 2023-11     1
# 2025-05     1
# 2025-06     4
# 2025-07    26
# 2025-08    32
# Freq: M, Name: count, dtype: int64
# ========================================

# %% [markdown]
# # Remark
# For JavaScript-heavy sites (requires selenium)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

def js_scrape(url):
    """Use when sites require JavaScript rendering"""
    options = Options()
    options.headless = True
    driver = webdriver.Chrome(options=options)
    driver.get(url)
    html = driver.page_source
    driver.quit()
    return html
